# %%
import seaborn as sb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
data=pd.read_csv('E:\\data analayz\\5\\data\\house.csv')
data
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address       Price  \
# 0      63     1     True       True      True             Shahran  1850000000
# 1      60     1     True       True      True             Shahran  1850000000
# 2      79     2     True       True      True              Pardis   550000000
# 3      95     2     True       True      True       Shahrake Qods   902500000
# 4     123     2     True       True      True      Shahrake Gharb  7000000000
# ...   ...   ...      ...        ...       ...                 ...         ...
# 3474   86     2     True       True      True  Southern Janatabad  3500000000
# 3475   83     2     True       True      True            Niavaran  6800000000
# 3476   75     2    False      False     False              Parand   365000000
# 3477  105     2     True       True      True              Dorous  5600000000
# 3478   82     2    False       True      True              Parand   360000000
#
#       Price(USD)
# ...

# %%
#data.info()
data.dtypes
# Out:
# Area           object
# Room            int64
# Parking          bool
# Warehouse        bool
# Elevator         bool
# Address        object
# Price           int64
# Price(USD)    float64
# dtype: object

# %%
data['Area']=pd.to_numeric(data['Area'],errors='coerce')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3473 non-null   float64
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   int64
#  7   Price(USD)  3479 non-null   float64
# dtypes: bool(3), float64(2), int64(2), object(1)
# memory usage: 146.2+ KB

# %%
data.replace({True:1,False:0},inplace=True)
data
# Out:
# C:\Users\ghost\AppData\Local\Temp\ipykernel_1628\4228065804.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({True:1,False:0},inplace=True)
#        Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3474   86.0     2        1          1         1  Southern Janatabad
# ...

# %%
data.isnull().sum() #جمع پرو خالیو بهم بگو
# Out:
# Area           6
# Room           0
# Parking        0
# Warehouse      0
# Elevator       0
# Address       23
# Price          0
# Price(USD)     0
# dtype: int64

# %%
data.dropna(inplace=True)#حذف خالی ها
data.isnull().sum()
# Out:
# Area          0
# Room          0
# Parking       0
# Warehouse     0
# Elevator      0
# Address       0
# Price         0
# Price(USD)    0
# dtype: int64

# %%
data.duplicated().sum()#تعداد تکراری ها
# Out:
# 208

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %%
data.reset_index(inplace=True,drop=True)#پاک کرد ردیف ایندکس رو
data
# Out:
#        Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63.0     1        1          1         1             Shahran
# 1      60.0     1        1          1         1             Shahran
# 2      79.0     2        1          1         1              Pardis
# 3      95.0     2        1          1         1       Shahrake Qods
# 4     123.0     2        1          1         1      Shahrake Gharb
# ...     ...   ...      ...        ...       ...                 ...
# 3237   63.0     1        1          1         0         Feiz Garden
# 3238   86.0     2        1          1         1  Southern Janatabad
# 3239   83.0     2        1          1         1            Niavaran
# 3240  105.0     2        1          1         1              Dorous
# 3241   82.0     2        0          1         1              Parand
#
#            Price  Price(USD)
# 0     1850000000    61666.67
# 1     1850000000    61666.67
# 2      550000000    18333.33
# 3      902500000    30083.33
# ...

# %%
b=set(data['Address'])
#s={}
add=dict()
for s,i in enumerate(b):
    add.update({i:s})
add
# Out:
# {'Mahmoudieh': 0,
#  'Parastar': 1,
#  'Railway': 2,
#  'Javadiyeh': 3,
#  'Seyed Khandan': 4,
#  'Varamin - Beheshti': 5,
#  'Tajrish': 6,
#  'Pishva': 7,
#  'Northern Janatabad': 8,
#  'Sadeghieh': 9,
#  'Shahr-e-Ziba': 10,
#  'Dehkade Olampic': 11,
#  'Air force': 12,
#  'Southern Janatabad': 13,
#  'Taslihat': 14,
#  'Keshavarz Boulevard': 15,
#  'Mehrabad River River': 16,
#  'Gholhak': 17,
#  'Shahedshahr': 18,
#  'ShahrAra': 19,
#  'Robat Karim': 20,
#  'Afsarieh': 21,
#  'Vahidieh': 22,
#  'Aliabad South': 23,
#  'Shahrake Gharb': 24,
#  'Shadabad': 25,
#  'Enghelab': 26,
#  'Dorous': 27,
#  'Dezashib': 28,
#  'Tehransar': 29,
#  'Aqdasieh': 30,
#  'Azarbaijan': 31,
#  'Eskandari': 32,
#  'Amirabad': 33,
#  'Southern Chitgar': 34,
#  'Malard': 35,
#  'Fallah': 36,
#  'Amirieh': 37,
#  'Punak': 38,
#  'Baghestan': 39,
#  'Bahar': 40,
#  'Islamshahr Elahieh': 41,
#  'Elahieh': 42,
#  'Darband': 43,
#  'Azadshahr': 44,
#  'Vanak': 45,
#  'Darabad': 46,
#  'Alborz Complex': 47,
# ...

# %%
c=['a','b','c','e']#مثال
for i,j in enumerate(c): #اولی جایگاه دومی خودش
    print(i,j)
# Out:
# 0 a
# 1 b
# 2 c
# 3 e

# %%
data.replace(add,inplace=True)#مثال
data
# Out:
# C:\Users\ghost\AppData\Local\Temp\ipykernel_1628\4230873339.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace(add,inplace=True)
#        Area  Room  Parking  Warehouse  Elevator  Address       Price  \
# 0      63.0     1        1          1         1       48  1850000000
# 1      60.0     1        1          1         1       48  1850000000
# 2      79.0     2        1          1         1      149   550000000
# 3      95.0     2        1          1         1      168   902500000
# 4     123.0     2        1          1         1       24  7000000000
# ...     ...   ...      ...        ...       ...      ...         ...
# 3237   63.0     1        1          1         0      144  1890000000
# ...

# %%
add['Shahran']#مثال
# Out:
# 48

# %%
data.info()#همه چی درسته
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3242 entries, 0 to 3241
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3242 non-null   float64
#  1   Room        3242 non-null   int64
#  2   Parking     3242 non-null   int64
#  3   Warehouse   3242 non-null   int64
#  4   Elevator    3242 non-null   int64
#  5   Address     3242 non-null   int64
#  6   Price       3242 non-null   int64
#  7   Price(USD)  3242 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 202.8 KB

# %%
x=data.iloc[:,:6]
y=data['Price']

# %%
x.shape
# Out:
# (3242, 6)

# %%
y.shape
# Out:
# (3242,)

# %% [markdown]
# ماشین لرنینک (نیاز به یادگیری نیست)

# %%
from sklearn.preprocessing import scale
x=scale(x)
y=scale(y)
# Out:
# C:\Users\ghost\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:261: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(

# %%
from sklearn.linear_model import Ridge

# %%
model=Ridge()
model.fit(x,y)
# Out:
# Ridge()

# %%
test=np.array([[65.0,3,0,1,1,183]])
test.shape
# Out:
# (1, 6)

# %%
model.predict(test)
# Out:
# array([35.16610504])
